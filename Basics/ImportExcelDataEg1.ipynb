# %%
#importing excel data into python
import pandas as pd
import xlrd

datasheet1=pd.read_excel('Optimisation_Exercise.xlsx',sheet_name='distances')
print(datasheet1)
datasheet2=pd.read_excel('Optimisation_Exercise.xlsx',sheet_name='cost_matrix')
print(datasheet2)


xls = pd.ExcelFile('Optimisation_Exercise.xlsx')
sheets = xls.sheet_names
print(sheets)

for i in range(len(sheets)):
    print(sheets[i])

print('stop')

df2=pd.DataFrame(datasheet1,columns=['Cityname'])
#print('dataset2',df2.values)
A=df2.values
print(A)
# Out:
#             Cityname  Barcelona  Belgrade   Berlin  Brussels  Bucharest  \
# 0          Barcelona       0.00   1528.13  1497.61   1062.89    1968.42
# 1           Belgrade    1528.13      0.00   999.25   1372.59     447.34
# 2             Berlin    1497.61    999.25     0.00    651.62    1293.40
# 3           Brussels    1062.89   1372.59   651.62      0.00    1769.69
# 4          Bucharest    1968.42    447.34  1293.40   1769.69       0.00
# 5           Budapest    1498.79    316.41   689.06   1131.52     639.77
# 6         Copenhagen    1757.54   1327.24   354.03    766.67    1571.54
# 7             Dublin    1469.29   2145.39  1315.16    773.20    2534.72
# 8            Hamburg    1471.78   1229.93   254.51    489.76    1544.17
# 9           Istanbul    2230.42    809.48  1735.01   2178.85     445.62
# 10              Kiev    2391.06    976.02  1204.00   1836.20     744.44
# 11            London    1137.67   1688.97   929.97    318.72    2088.42
# ...
